# %%
import pandas as pd

df = pd.read_csv('sophia/cleaned_wrong_labels.csv')
df.head()
# Out:
#              video_id                      label modality  label_correct  \
# 0  -0Zg_dXR_6I_000013             fire crackling      NaN          False
# 1  -0pJqpNjft4_000267        car engine starting      NaN          False
# 2  --U7joUcTCo_000000  male speech, man speaking      NaN          False
# 3  -2sE5CH8Wb8_000030           printer printing      NaN          False
# 4  -3-4qmWSJXU_000030        car engine starting      NaN          False
#
#    modality_correct                                   suggested_labels  \
# 0             False  [{"label": "missile launch", "label_correct": ...
# 1              True                                                 []
# 2              True  [{"label": "people belly laughing", "modality"...
# 3             False  [{"label": "reversing beeps", "modality": "aud...
# 4             False         [{"label": "thunder", "modality": "both"}]
#
#   suggested_modality                                             reason  \
# ...

# %%
len(df)
# Out:
# 5034
